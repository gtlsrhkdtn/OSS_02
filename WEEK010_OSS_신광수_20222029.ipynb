# %%
#1
a = [1, 2, 3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
#2-1
class Gizmo:
  def __init__(self):
    print('Gizmo id: %d' % id(self))

x = Gizmo()
# Out:
# Gizmo id: 133116437518800

# %%
#2-2
y = Gizmo() * 10
# Out:
# Gizmo id: 133116435311136
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1018307269.py in <cell line: 0>()
#       1 #2-2
# ----> 2 y = Gizmo() * 10
#
# TypeError: unsupported operand type(s) for *: 'Gizmo' and 'int'

# %%
#2-3
dir()
# Out:
# ['Gizmo',
#  'In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x']

# %%
#3-1
charles = {'name': 'Charles L. Dodgson', 'born' : 1832}
lewis = charles

# %%
#3-2
lewis is charles
# Out:
# True

# %%
#3-3
id(charles), id(lewis)
# Out:
# (133116418703232, 133116418703232)

# %%
#3-4
lewis['balance'] = 950
charles
# Out:
# {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}

# %%
#4-1
alex = {'name' : 'Charles L. Dodgson', 'born' : 1832, 'balance': 950}
alex == charles
# Out:
# True

# %%
#4-2
alex is charles
# Out:
# False

# %%
#5-1
t1 = (1, 2, [30, 40])
t2 = (1, 2, [30, 40])
t1 == t2, t1 is t2
# Out:
# (True, False)

# %%
#5-2
id(t1[-1])
# Out:
# 133116420235456

# %%
#5-3
t1[-1].append(99)
t1, id(t1[-1])
# Out:
# ((1, 2, [30, 40, 99]), 133116420235456)

# %%
#5-4
t1 == t2
# Out:
# False

# %%
#6-1
l1 = [3, [66, 55, 44], (7, 8, 9)]
l2 = list(l1)

# %%
#6-2
l1.append(100)

# %%
#6-3
l1[1].remove(55)
print("l1: ",l1)
print("l2: ", l2)
# Out:
# l1:  [3, [66, 44], (7, 8, 9), 100]
# l2:  [3, [66, 44], (7, 8, 9)]

# %%
#6-4
l2[1] += [33, 22]

# %%
#6-5
l2[2] += (10, 11)

print("l1: ",l1)
print("l2: ", l2)
# Out:
# l1:  [3, [66, 44, 33, 22, 33, 22], (7, 8, 9), 100]
# l2:  [3, [66, 44, 33, 22, 33, 22], (7, 8, 9, 10, 11)]

# %%
#7
class Bus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
#8-1
import copy
bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)
id(bus1), id(bus2), id(bus3)
# Out:
# (133116435373840, 133116435376192, 133116435376960)

# %%
#8-2
bus1.drop('Bill')
bus1.passengers, bus2.passengers, bus3.passengers
# Out:
# (['Alice', 'Claire', 'David'],
#  ['Alice', 'Claire', 'David'],
#  ['Alice', 'Bill', 'Claire', 'David'])

# %%
#8-3
id(bus1.passengers), id(bus2.passengers), id(bus3.passengers)
# Out:
# (133116417463872, 133116417463872, 133116417404288)

# %%
#9-1
a = [10, 20]
b = [a, 30]
a.append(b)
a
# Out:
# [10, 20, [[...], 30]]

# %%
#9-2
c = copy.deepcopy(a)
c
# Out:
# [10, 20, [[...], 30]]

# %%
#10-1
def f(a, b):
  a += b
  return a

# %%
#10-2
a = [1, 2]
b = [3, 4]
f(a, b), (a, b)
# Out:
# ([1, 2, 3, 4], ([1, 2, 3, 4], [3, 4]))

# %%
#10-3
x = 1
y = 2
f(x, y), (x, y)
# Out:
# (3, (1, 2))

# %%
#10-4
t = (10, 20)
u = 30, 40
f(t, u), (t, u)
# Out:
# ((10, 20, 30, 40), ((10, 20), (30, 40)))

# %%
#11
class HauntedBus:
  """유령 승객이 출몰하는 버스 모델"""

  def __init__(self, passengers = []):
    self.passengers = passengers

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#12-1
bus1 = HauntedBus(['Alice', 'Bill'])
bus1.passengers
# Out:
# ['Alice', 'Bill']

# %%
#12-2
bus1.pick('Charlie')
bus1.drop('Alice')
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
#12-3
bus2 = HauntedBus()
bus2.pick('Carrie')
bus2.passengers
# Out:
# ['Carrie']

# %%
#12-4
bus3 = HauntedBus()
bus3.passengers
# Out:
# ['Carrie']

# %%
#12-5
bus3.pick('Dave')
bus2.passengers
# Out:
# ['Carrie', 'Dave']

# %%
#12-6
bus2.passengers is bus3.passengers
# Out:
# True

# %%
#12-7
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
#12-8
HauntedBus.__init__.__defaults__
# Out:
# (['Carrie', 'Dave'],)

# %%
#12-9
HauntedBus.__init__.__defaults__[0] is bus2.passengers
# Out:
# True

# %%
#13
class TwilightBus:
  """승객이 사라지게 만드는 버스 모델"""

  def __init__(self, passengers = None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = passengers

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#14
basketball_team = ['Sue', 'Tina', 'Maya', 'Dina', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Maya', 'Dina']

# %%
#15
class TwilightBus:
  """승객이 사라지게 만드는 버스 모델"""

  def __init__(self, passengers = None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#16
basketball_team = ['Sue', 'Tina', 'Maya', 'Dina', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Tina', 'Maya', 'Dina', 'Pat']

# %%
#17-1
import weakref
s1 = {1, 2, 3}
s2 = s1

def bye():
  print('Gone with th wind...')

# %%
#17-2
ender = weakref.finalize(s1, bye)
ender.alive
# Out:
# True

# %%
#17-3
del s1
ender.alive
# Out:
# True

# %%
#17-4
s2 = 'spam'
# Out:
# Gone with th wind...

# %%
#17-5
ender.alive
# Out:
# False
