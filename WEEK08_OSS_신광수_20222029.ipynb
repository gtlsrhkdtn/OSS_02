# %%
#1-1
def deco(func):
  def inner():
    print('running inner()')
  return inner

# %%
#1-2
@deco
def target():
  print("running target()")

target()
# Out:
# running inner()

# %%
#1-3
target
# Out:
# <function __main__.deco.<locals>.inner()>

# %%
#1-Decorator
def logger(func):
  def wrapper(*args, **kwargs):
    print(f"[LOG] {func.__name__} called with args={args}, kwargs={kwargs}")
    result = func(*args, **kwargs)
    print(f"[LOG] {func.__name__} returned {result}")
    return result
  return wrapper

@logger
def add(a, b):
  return a+b

# %%
#2
registry = []

def register(func):
  print('running register(%s)' % func)
  registry.append(func)
  return func

@register
def f1():
  print('running f1()')

@register
def f2():
  print('running f2()')

def f3():
  print('running f3()')

def main():
  print('running main()')
  print('registry ->', registry)
  f1()
  f2()
  f3()

if __name__=='__main__':
  main()
# Out:
# running register(<function f1 at 0x7d9532817880>)
# running register(<function f2 at 0x7d9532817420>)
# running main()
# registry -> [<function f1 at 0x7d9532817880>, <function f2 at 0x7d9532817420>]
# running f1()
# running f2()
# running f3()

# %%
#3
promos = []

def promotion(promo_func):
  """promotion() decorator는 promo)func를 promos 리스트에 추가한 후 그대로 반환"""
  promos.append(promo_func)
  return promo_func

@promotion
def fidelity_promo(order):
  """충성도 점수가 1000점 이상인 고객에게 전체 5% 할인 적용"""
  return order.total() * 0.05 if order.customer.fidelity >= 1000 else 0

@promotion
def bulk_item_promo(order):
  """20개 이상의 동일 상품을 구입하면 10% 할인 적용"""
  discount = 0
  for item in order.cart:
    if item.quantity >= 20:
      discount += item.total() * 0.1
  return discount

@promotion
def large_order_promo(order):
  """10종류 이상의 상품을 구입하면 전체 7% 할인 적용"""
  distinct_items = {item.product for item in order.cart}
  if len(distinct_items) >= 10:
    return order.total() * 0.07
  return 0

def best_promo(order):
  """최대로 할인받을 금액을 반환한다."""
  return max(promo(order) for promo in promos)

# %%
#4-1
def f1(a):
  print(a)
  print(b)

f1(3)
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1461815370.py in <cell line: 0>()
#       4   print(b)
#       5
# ----> 6 f1(3)
#
# /tmp/ipython-input-1461815370.py in f1(a)
#       2 def f1(a):
#       3   print(a)
# ----> 4   print(b)
#       5
#       6 f1(3)
#
# NameError: name 'b' is not defined

# %%
#4-2
b = 6
f1(3)
# Out:
# 3
# 6

# %%
#5
b = 6
def f2(a):
  print(a)
  print(b)
  b = 9

f2(3)
# Out:
# 3
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-977824078.py in <cell line: 0>()
#       6   b = 9
#       7
# ----> 8 f2(3)
#
# /tmp/ipython-input-977824078.py in f2(a)
#       3 def f2(a):
#       4   print(a)
# ----> 5   print(b)
#       6   b = 9
#       7
#
# UnboundLocalError: cannot access local variable 'b' where it is not associated with a value

# %%
#6-1
b = 6
def f3(a):
  global b
  print(a)
  print(b)
  b = 9

f3(3)
# Out:
# 3
# 6

# %%
#6-2
f3(3)
# Out:
# 3
# 9

# %%
#6-3
b = 30
f3(3)
# Out:
# 3
# 30

# %%
#7-1
class Averager():
  def __init__(self):
    self.series = []

  def __call__(self, new_value):
    self.series.append(new_value)
    total = sum(self.series)
    return total/len(self.series)

# %%
#7-2
avg = Averager()
avg(10)
# Out:
# 10.0

# %%
#7-3
avg(11)
# Out:
# 10.5

# %%
#7-4
avg(12)
# Out:
# 11.0

# %%
#8-1
def make_averager():
  series = []

  def averager(new_value):
    series.append(new_value)
    total = sum(series)
    return total/len(series)

  return averager

# %%
#8-2
avg = make_averager()
avg(10)
# Out:
# 10.0

# %%
#8-3
avg(11)
# Out:
# 10.5

# %%
#8-4
avg(12)
# Out:
# 11.0

# %%
#9-1
avg.__code__.co_varnames
# Out:
# ('new_value', 'total')

# %%
#9-2
avg.__code__.co_freevars
# Out:
# ('series',)

# %%
#9-3
avg.__closure__
# Out:
# (<cell at 0x7d9531637f70: list object at 0x7d9531bd1880>,)

# %%
#9-4
avg.__closure__[0].cell_contents
# Out:
# [10, 11, 12]

# %%
#10-1
def make_averager():
  count = 0
  total = 0

  def averager(new_value):
    count += 1
    total += new_value
    return total / count

  return averager

# %%
#10-2
avg = make_averager()
avg(10)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-3687925560.py in <cell line: 0>()
#       1 #10-2
#       2 avg = make_averager()
# ----> 3 avg(10)
#
# /tmp/ipython-input-3791243733.py in averager(new_value)
#       5
#       6   def averager(new_value):
# ----> 7     count += 1
#       8     total += new_value
#       9     return total / count
#
# UnboundLocalError: cannot access local variable 'count' where it is not associated with a value

# %%
#11-1
def make_averager():
  count = 0
  total = 0

  def averager(new_value):
    nonlocal count, total
    count += 1
    total += new_value
    return total / count

  return averager

# %%
#11-2
avg = make_averager()
avg(10)
# Out:
# 10.0

# %%
#12
import time

def clock(func):
  def clocked(*args):
    t0 = time.perf_counter()
    result = func(*args)
    elapsed = time.perf_counter() - t0
    name = func.__name__
    args_str = ', '.join(repr(arg) for arg in args)
    print('[%0.8fs] %s(%s) -> %r' % (elapsed, name, args_str, result))
    return result
  return clocked

# %%
#13-1
@clock
def snooze(seconds):
  time.sleep(seconds)

@clock
def factorial(n):
  return 1 if n < 2 else n*factorial(n-1)

if __name__=='__main__':
  print('*'*40, 'Calling snooze(.123)')
  snooze(.123)
  print('*'*40, 'Calling factoral(6)')
  print('6! =', factorial(6))
# Out:
# **************************************** Calling snooze(.123)
# [0.12392462s] snooze(0.123) -> None
# **************************************** Calling factoral(6)
# [0.00000056s] factorial(1) -> 1
# [0.00001181s] factorial(2) -> 2
# [0.00001837s] factorial(3) -> 6
# [0.00002548s] factorial(4) -> 24
# [0.00003103s] factorial(5) -> 120
# [0.00003807s] factorial(6) -> 720
# 6! = 720

# %%
#13-2
factorial.__name__
# Out:
# 'clocked'

# %%
#14-1
import time
import functools

def clock(func):
  @functools.wraps(func)
  def clocked(*args, **kwargs):
    t0 = time.time()
    result = func(*args, **kwargs)
    elapsed = time.time() - t0
    arg_lst = []
    name = func.__name__
    if args:
      arg_lst.append(', '.join(repr(arg) for arg in args))
    if kwargs:
      pairs = ['%s=%r' % (k,w) for k,w in sorted(kwargs.items())]
      arg_lst.append(', '.join(pairs))
    arg_str = ', '.join(arg_lst)
    print('[%0.8fs] %s(%s) -> %r' % (elapsed, name, arg_str, result))
    return result
  return clocked

# %%
#14-2
@clock
def snooze(seconds):
  time.sleep(seconds)

@clock
def factorial(n):
  return 1 if n < 2 else n * factorial(n-1)

if __name__=='__main__':
  print('*'*40, 'Calling snooze(.123)')
  snooze(.123)
  print('*'*40, 'Calling factorial(6)')
  print('6! =', factorial(6))
# Out:
# **************************************** Calling snooze(.123)
# [0.12366772s] snooze(0.123) -> None
# **************************************** Calling factorial(6)
# [0.00000072s] factorial(1) -> 1
# [0.00001383s] factorial(2) -> 2
# [0.00002098s] factorial(3) -> 6
# [0.00002742s] factorial(4) -> 24
# [0.00003433s] factorial(5) -> 120
# [0.00004363s] factorial(6) -> 720
# 6! = 720
